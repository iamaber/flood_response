# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('flood_response_dummy.csv')
# Set id as index
df.set_index('id', inplace=True)

df.head()
# Out:
#          caller_name       caller_mobile  gender  physically_challenged  \
# id
# 6043       Amy Smith    001-876-846-3517  Female                      1
# 2781   James Johnson  640-507-9038x56016    Male                      1
# 4166      Troy Baker   (856)917-6898x082    Male                      0
# 7899   Sandra Larson   482-626-0420x0391    Male                      1
# 7280  Sharon Griffin             #ERROR!    Male                      1
#
#      location_district   location_upazila location_union caller_need  \
# id
# 6043             Dhaka          Sitakunda       Mahilara       Other
# 2781            Khulna             Sarail      Kusanghal        None
# 4166             Dhaka  Cox's Bazar Sadar       Udaykati       Other
# 7899             Dhaka             Barura       Batajore        Food
# 7280        Chattogram        Brahmanpara          Magar       Other
#
#                                                 summary  \
# id
# 6043                                   Girl score hair.
# 2781    Rate break major American subject culture rule.
# 4166                  From lead minute building common.
# 7899    First run recognize season section buy outside.
# 7280  Place building water at indeed character ident...
#
#                                                  note   status  \
# id
# 6043  Face wall employee participant car owner laugh.     None
# 2781          Up present east morning arrive product.  Unknown
# 4166          Very hair few ready kitchen sea pretty.  Unknown
# 7899   Laugh quality drug end various determine film.     None
# 7280         Face without free red difference office.     None
#
#      resolve_organization               resolve_by           created_at
# id
# 6043                 BRAC          Daniel Mcdonald  2024-03-10 10:26:08
# 2781                 BRAC            Tristan Myers  2024-01-28 07:21:20
# 4166           Local Govt       Heather Hardin DDS  2024-05-04 09:12:06
# 7899                 BRAC  Kimberly Montgomery PhD  2024-03-25 23:51:13
# 7280            Red Cross             Amy Davis MD  2024-05-20 14:43:39

# %%
# Function to plot pie chart
import matplotlib.pyplot as plt
import seaborn as sns

def plot_pie_chart(data, title):
    # Set the style using Seaborn
    sns.set_style("whitegrid")
    sns.set_palette("pastel")
    
    # Create the figure and axis with a smaller size
    fig, ax = plt.subplots(figsize=(8, 6))
    
    # Explode the largest slice
    explode = [0.1 if i == data.values.argmax() else 0 for i in range(len(data))]
    
    # Create the pie chart
    wedges, texts, autotexts = ax.pie(data.values, 
                                      autopct='%1.1f%%',
                                      explode=explode,
                                      shadow=True,
                                      startangle=90,
                                      pctdistance=0.75)

    # Enhance the appearance of the percentage labels
    for autotext in autotexts:
        autotext.set_fontsize(8) 
        autotext.set_weight('bold')
    
    # Add a circle at the center to create a donut chart effect
    centre_circle = plt.Circle((0, 0), 0.50, fc='white')
    fig.gca().add_artist(centre_circle)
    
    # Add title and adjust its appearance
    ax.set_title(title, fontsize=16, fontweight='bold', pad=20) 

    # Add a legend
    ax.legend(wedges, data.index,
              title="Categories",
              loc="center left",
              bbox_to_anchor=(1, 0, 0.5, 1),
              fontsize=8) 

    plt.tight_layout()
    plt.show()

# %%
# 1. Gender analysis
gender_counts = df['gender'].value_counts()
print("Gender Frequency:")
print(gender_counts)
print("\nGender Percentage:")
print(gender_counts / len(df) * 100)
plot_pie_chart(gender_counts, 'Gender Distribution')
# Out:
# Gender Frequency:
# Male      505
# Female    495
# Name: gender, dtype: int64
#
# Gender Percentage:
# Male      50.5
# Female    49.5
# Name: gender, dtype: float64

# %%
# 2. Physically Challenged analysis
physically_challenged_counts = df['physically_challenged'].value_counts()
print("\nPhysically Challenged Frequency:")
print(physically_challenged_counts)
print("\nPhysically Challenged Percentage:")
print(physically_challenged_counts / len(df) * 100)
plot_pie_chart(physically_challenged_counts, 'Physically Challenged Distribution')
# Out:
# Physically Challenged Frequency:
# 0    505
# 1    495
# Name: physically_challenged, dtype: int64
#
# Physically Challenged Percentage:
# 0    50.5
# 1    49.5
# Name: physically_challenged, dtype: float64

# %%
# 3. Caller Need analysis
caller_need_counts = df['caller_need'].value_counts()
print("\nCaller Need Frequency:")
print(caller_need_counts)
print("\nCaller Need Percentage:")
print(caller_need_counts / len(df) * 100)
plot_pie_chart(caller_need_counts, 'Caller Need Distribution')
# Out:
# Caller Need Frequency:
# Food        214
# Rescue      207
# Other       201
# Medicine    198
# None        180
# Name: caller_need, dtype: int64
#
# Caller Need Percentage:
# Food        21.4
# Rescue      20.7
# Other       20.1
# Medicine    19.8
# None        18.0
# Name: caller_need, dtype: float64

# %%
# 4. Status analysis
status_counts = df['status'].value_counts()
print("\nStatus Frequency:")
print(status_counts)
print("\nStatus Percentage:")
print(status_counts / len(df) * 100)
plot_pie_chart(status_counts, 'Status Distribution')
# Out:
# Status Frequency:
# Action Taken    269
# Unknown         255
# Resolved        245
# None            231
# Name: status, dtype: int64
#
# Status Percentage:
# Action Taken    26.9
# Unknown         25.5
# Resolved        24.5
# None            23.1
# Name: status, dtype: float64

# %%
# 5. Resolve Organization analysis
resolve_org_counts = df['resolve_organization'].value_counts()
print("\nResolve Organization Frequency:")
print(resolve_org_counts)
print("\nResolve Organization Percentage:")
print(resolve_org_counts / len(df) * 100)
plot_pie_chart(resolve_org_counts, 'Resolve Organization Distribution')
# Out:
# Resolve Organization Frequency:
# Local Govt    271
# BRAC          260
# Red Cross     241
# NGO           228
# Name: resolve_organization, dtype: int64
#
# Resolve Organization Percentage:
# Local Govt    27.1
# BRAC          26.0
# Red Cross     24.1
# NGO           22.8
# Name: resolve_organization, dtype: float64
